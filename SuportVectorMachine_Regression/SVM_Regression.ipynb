# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import make_regression

# %%
X,y= make_regression(n_samples=1000,n_features=2,n_targets=1,noise=3.0)

# %%
X.shape,y.shape
# Out:
# ((1000, 2), (1000,))

# %%
## split dataset into training and testing dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel= 'linear')

# %%
svr.fit(X_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred = svr.predict(X_test)

# %%
### Check model accuracy 
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9993086348166687

# %% [markdown]
# ### HyperparameterTunning

# %%
from sklearn.model_selection import GridSearchCV

parameter = {
    'C':[0.1,1,10,100,1000],
    'gamma':[1,0.1,0.001,0.0001]
}

# %%
grid = GridSearchCV(SVR(),param_grid= parameter , refit=True,cv = 5, verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001}

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.092 total time=   0.0s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.107 total time=   0.0s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.109 total time=   0.0s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.092 total time=   0.0s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.120 total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.107 total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.113 total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.116 total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.111 total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.119 total time=   0.0s
# [CV 1/5] END ...............C=0.1, gamma=0.001;, score=-0.000 total time=   0.0s
# [CV 2/5] END ...............C=0.1, gamma=0.001;, score=-0.009 total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.001;, score=0.002 total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.001;, score=0.001 total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.001;, score=0.002 total time=   0.0s
# [CV 1/5] END ..............C=0.1, gamma=0.0001;, score=-0.002 total time=   0.0s
# [CV 2/5] END ..............C=0.1, gamma=0.0001;, score=-0.011 total time=   0.0s
# [CV 3/5] END ...............C=0.1, gamma=0.0001;, score=0.000 total time=   0.0s
# [CV 4/5] END ..............C=0.1, gamma=0.0001;, score=-0.001 total time=   0.0s
# [CV 5/5] END ...............C=0.1, gamma=0.0001;, score=0.000 total time=   0.0s
# [CV 1/5] END ......................C=1, gamma=1;, score=0.535 total time=   0.0s
# [CV 2/5] END ......................C=1, gamma=1;, score=0.670 total time=   0.0s
# [CV 3/5] END ......................C=1, gamma=1;, score=0.620 total time=   0.0s
# [CV 4/5] END ......................C=1, gamma=1;, score=0.535 total time=   0.0s
# [CV 5/5] END ......................C=1, gamma=1;, score=0.648 total time=   0.0s
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.789 total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.856 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.824 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.804 total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.835 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.018 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.010 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.021 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.020 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.021 total time=   0.0s
# [CV 1/5] END ................C=1, gamma=0.0001;, score=-0.000 total time=   0.0s
# [CV 2/5] END ................C=1, gamma=0.0001;, score=-0.009 total time=   0.0s
# [CV 3/5] END .................C=1, gamma=0.0001;, score=0.002 total time=   0.0s
# [CV 4/5] END .................C=1, gamma=0.0001;, score=0.001 total time=   0.0s
# [CV 5/5] END .................C=1, gamma=0.0001;, score=0.002 total time=   0.0s
# [CV 1/5] END .....................C=10, gamma=1;, score=0.877 total time=   0.0s
# [CV 2/5] END .....................C=10, gamma=1;, score=0.989 total time=   0.0s
# [CV 3/5] END .....................C=10, gamma=1;, score=0.945 total time=   0.0s
# [CV 4/5] END .....................C=10, gamma=1;, score=0.912 total time=   0.0s
# [CV 5/5] END .....................C=10, gamma=1;, score=0.937 total time=   0.0s
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.970 total time=   0.0s
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.994 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.985 total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.977 total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.984 total time=   0.0s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.196 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.195 total time=   0.0s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.199 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.198 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.203 total time=   0.0s
# [CV 1/5] END ................C=10, gamma=0.0001;, score=0.019 total time=   0.0s
# [CV 2/5] END ................C=10, gamma=0.0001;, score=0.010 total time=   0.0s
# [CV 3/5] END ................C=10, gamma=0.0001;, score=0.021 total time=   0.0s
# [CV 4/5] END ................C=10, gamma=0.0001;, score=0.020 total time=   0.0s
# [CV 5/5] END ................C=10, gamma=0.0001;, score=0.021 total time=   0.0s
# [CV 1/5] END ....................C=100, gamma=1;, score=0.962 total time=   0.0s
# [CV 2/5] END ....................C=100, gamma=1;, score=0.999 total time=   0.0s
# [CV 3/5] END ....................C=100, gamma=1;, score=0.991 total time=   0.0s
# [CV 4/5] END ....................C=100, gamma=1;, score=0.985 total time=   0.0s
# [CV 5/5] END ....................C=100, gamma=1;, score=0.982 total time=   0.0s
# [CV 1/5] END ..................C=100, gamma=0.1;, score=0.996 total time=   0.0s
# [CV 2/5] END ..................C=100, gamma=0.1;, score=0.999 total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.998 total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=0.1;, score=0.998 total time=   0.0s
# [CV 5/5] END ..................C=100, gamma=0.1;, score=0.997 total time=   0.0s
# [CV 1/5] END ................C=100, gamma=0.001;, score=0.995 total time=   0.0s
# [CV 2/5] END ................C=100, gamma=0.001;, score=0.996 total time=   0.0s
# [CV 3/5] END ................C=100, gamma=0.001;, score=0.995 total time=   0.0s
# [CV 4/5] END ................C=100, gamma=0.001;, score=0.995 total time=   0.0s
# [CV 5/5] END ................C=100, gamma=0.001;, score=0.996 total time=   0.0s
# [CV 1/5] END ...............C=100, gamma=0.0001;, score=0.197 total time=   0.0s
# [CV 2/5] END ...............C=100, gamma=0.0001;, score=0.196 total time=   0.0s
# [CV 3/5] END ...............C=100, gamma=0.0001;, score=0.200 total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=0.0001;, score=0.200 total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=0.0001;, score=0.204 total time=   0.0s
# [CV 1/5] END ...................C=1000, gamma=1;, score=0.976 total time=   0.2s
# [CV 2/5] END ...................C=1000, gamma=1;, score=0.999 total time=   0.1s
# [CV 3/5] END ...................C=1000, gamma=1;, score=0.991 total time=   0.1s
# [CV 4/5] END ...................C=1000, gamma=1;, score=0.994 total time=   0.1s
# [CV 5/5] END ...................C=1000, gamma=1;, score=0.992 total time=   0.1s
# [CV 1/5] END .................C=1000, gamma=0.1;, score=0.999 total time=   0.0s
# [CV 2/5] END .................C=1000, gamma=0.1;, score=0.999 total time=   0.0s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.999 total time=   0.0s
# [CV 4/5] END .................C=1000, gamma=0.1;, score=0.999 total time=   0.0s
# [CV 5/5] END .................C=1000, gamma=0.1;, score=0.999 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=0.001;, score=0.999 total time=   0.0s
# [CV 2/5] END ...............C=1000, gamma=0.001;, score=0.999 total time=   0.0s
# [CV 3/5] END ...............C=1000, gamma=0.001;, score=0.999 total time=   0.0s
# [CV 4/5] END ...............C=1000, gamma=0.001;, score=0.999 total time=   0.0s
# [CV 5/5] END ...............C=1000, gamma=0.001;, score=0.999 total time=   0.0s
# [CV 1/5] END ..............C=1000, gamma=0.0001;, score=0.996 total time=   0.0s
# [CV 2/5] END ..............C=1000, gamma=0.0001;, score=0.996 total time=   0.0s
# [CV 3/5] END ..............C=1000, gamma=0.0001;, score=0.996 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=0.0001;, score=0.995 total time=   0.0s
# [CV 5/5] END ..............C=1000, gamma=0.0001;, score=0.996 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.001, 0.0001]},
#              verbose=3)

# %%
y_grid_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_grid_pred,y_test)
# Out:
# 0.9993110203069314
